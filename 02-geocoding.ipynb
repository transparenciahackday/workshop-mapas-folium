# %% [markdown]
# # Geocoding em Python
#
# Vamos experimentar determinar as coordenadas de um sítio a partir da morada.

# %%
# !pip install geocoder

import geocoder
import pandas as pd
import folium

# %%
location = "Praça Coronel Pacheco, Porto, Portugal"

g = geocoder.google(location)
g.latlng
# Out:
# [41.1515029, -8.6150322]

# %%
# outro provider, que o Google é limitado

g = geocoder.komoot(location)
g.latlng
# Out:
# [41.151237300000005, -8.61501626564905]

# %%
df = pd.read_csv('data/hamburguerias_porto.csv')
df.head()
# Out:
#                         nome                     morada      país localidade  \
# 0          Honorato Clérigos   Rua Cândido dos Reis, 12  Portugal      Porto
# 1                     Prégar  Largo de São Domingos, 96  Portugal      Porto
# 2  Nook Hamburgaria Pregaria      Rua São João Brito 32  Portugal      Porto
# 3             Alta Burguesia      Rua da Restauração, 1  Portugal      Porto
# 4                    De Gema        Rua do Almada, 253   Portugal      Porto
#
#   codigo_postal data_abertura
# 0      4050-151    2016-08-04
# 1      4050-253    2016-07-30
# 2           NaN    2016-06-01
# 3           NaN    2016-04-21
# 4      4050-038    2016-03-21

# %%
from time import sleep

for index, row in df.iterrows():
    # definir a morada completa que queremos procurar
    location = '{}, {}, {}'.format(row['morada'], row['localidade'], 'Portugal')
    # usar o serviço de geocoding para a encontrar
    g = geocoder.google(location)
    # calmex para não pressionar o servidor
    sleep(2)
    # caso encontre um valor, guardar no dataframe
    if g.latlng:
        df.at[index, 'lat'] = g.latlng[0]
        df.at[index, 'lon'] = g.latlng[1]
    print(location + str(g.latlng))

# gravar o resultado num novo ficheiro
df.to_csv('data/hamburguerias_porto_latlon.csv')
# Out:
# Rua Cândido dos Reis, 12, Porto, Portugal[41.14637219999999, -8.6139456]
# Largo de São Domingos, 96, Porto, Portugal[41.1429302, -8.614492199999999]
# Rua São João Brito 32, Porto, PortugalNone
# Rua da Restauração, 1, Porto, Portugal[41.1461432, -8.618476099999999]
# Rua do Almada, 253 , Porto, Portugal[41.1488928, -8.6121555]
# Via do Castelo do Queijo, 395, Porto, Portugal[41.1716409, -8.6879098]
# Rua Amândio Galhano, 51, Porto, Portugal[41.1834135, -8.5990883]
# Rua de Ceuta, 63, Porto, Portugal[41.1481994, -8.6139726]
# Rua Adolfo Casais Monteiro, 17, Porto, PortugalNone
# Praça do Bom Sucesso, 132, Porto, Portugal[41.1551953, -8.6286082]
# Rua da Conceição, 106, Porto, Portugal[41.1499904, -8.614575499999999]
# Praça Guilherme Gomes Fernandes, 39, Porto, Portugal[41.14764599999999, -8.6149398]
# Passeio de São Lázaro, 51, Porto, Portugal[41.1464207, -8.6020913]
# Rua do Ateneu Comercial 8-14, Porto, PortugalNone
# Rua Senhora da Luz, 448, Porto, Portugal[41.1527327, -8.6780075]
# Rua Martires da Liberdade 130 , Porto, Portugal[41.1512688, -8.6138888]
# Rua das Galeria de Paris, 113, Porto, PortugalNone
# Rua das Oliveiras, 118, Porto, Portugal[41.1497835, -8.6147197]
# Praça Dom Afonso V, 55, Porto, PortugalNone
# Rua de Diu, Porto, Portugal[41.1536528, -8.675354000000002]
# Avenida de Fernão de Magalhães, 500, Porto, PortugalNone
# Rua do Padrão, 152, Porto, PortugalNone
# Rua da Conceição, 59, Porto, PortugalNone
# Rua da Picaria, 87, Porto, Portugal[41.1496114, -8.612988999999999]
# Rua de Cândido dos Reis, 126, Porto, PortugalNone
# Rua da Torrinha, 134, Porto, Portugal[41.1525646, -8.620042699999999]
# Avenida do Brasil, 829, Porto, Portugal[41.159052, -8.6832975]
# Praça Dona Filipa de Lencastre, 183, Porto, Portugal[41.14835009999999, -8.6125981]
# Rua da Picaria, 89, Porto, Portugal[41.1496324, -8.612989299999999]
# Rua Professor Mota Pinto, 12, Porto, Portugal[41.1666198, -8.6500919]
# Rua Santa Catarina, 1433, Porto, Portugal[41.15891999999999, -8.6045798]
# Rua de Miguel Bombarda, 598, Porto, PortugalNone
# Rua da Arroteia, 21, Porto, PortugalNone
# Praça de Guilherme Gomes Fernandes, 67, Porto, Portugal[41.1478898, -8.614921599999999]
# Rua de Cedofeita, 263, Porto, Portugal[41.1511501, -8.6172688]
# Rua de Miragaia, 54, Porto, Portugal[41.1425162, -8.6198185]
# Rua do Almada, 120, Porto, Portugal[41.1472772, -8.6121176]
# Rua de Santa Catarina, 591, Porto, Portugal[41.151446, -8.6052556]
# Rua Egas Moniz, 490, Porto, Portugal[41.1630166, -8.622359399999999]
# Rua de Cedofeita, 382, Porto, PortugalNone
# Rua de Cedofeita, 50, Porto, PortugalNone

# %%
# conferir que ficou como queríamos
df.head(30)
# Out:
#     Unnamed: 0                             nome  \
# 0            0                Honorato Clérigos
# 1            1                           Prégar
# 2            2        Nook Hamburgaria Pregaria
# 3            3                   Alta Burguesia
# 4            4                          De Gema
# 5            5                       A Burguesa
# 6            6                Tasquinha do Caco
# 7            7              Dona Maria Pregaria
# 8            8           Boulevard Burger House
# 9            9                       NY Sliders
# 11          11                          Ó Maria
# 12          12                   Prego da Baixa
# 13          13                Tasquinha do Caco
# 14          14                          Munchie
# 15          15                            Peebz
# 16          16  Black Mamba - Burgers & Records
# 17          17                HD BAR TO BE WILD
# 18          18                      Zé do Prego
# 19          19                         Caffe.55
# 20          20          Hamburgueria do Mercado
# 21          21                       Quinhentos
# 22          22                       Casa Vasco
# 23          23                    SINS Sandwich
# 24          24                     Baixa Burger
# 26          26         Pão que ladra Destilaria
# 27          27      Real Hamburgaria Portuguesa
# 28          28                        Nova Copa
# 29          29                          Munchie
# 30          30                     Baixa Burger
# 31          31                 Ideias com Sabor
#
#                                  morada      país localidade codigo_postal  \
# 0              Rua Cândido dos Reis, 12  Portugal      Porto      4050-151
# 1             Largo de São Domingos, 96  Portugal      Porto      4050-253
# 2                 Rua São João Brito 32  Portugal      Porto           NaN
# 3                 Rua da Restauração, 1  Portugal      Porto           NaN
# 4                   Rua do Almada, 253   Portugal      Porto      4050-038
# 5         Via do Castelo do Queijo, 395  Portugal      Porto      4100-429
# 6               Rua Amândio Galhano, 51  Portugal      Porto           NaN
# 7                      Rua de Ceuta, 63  Portugal      Porto           NaN
# 8        Rua Adolfo Casais Monteiro, 17  Portugal      Porto           NaN
# 9             Praça do Bom Sucesso, 132  Portugal      Porto           NaN
# 11                Rua da Conceição, 106  Portugal      Porto           NaN
# 12  Praça Guilherme Gomes Fernandes, 39  Portugal      Porto           NaN
# 13            Passeio de São Lázaro, 51  Portugal      Porto           NaN
# 14         Rua do Ateneu Comercial 8-14  Portugal      Porto           NaN
# 15              Rua Senhora da Luz, 448  Portugal      Porto      4150-695
# 16       Rua Martires da Liberdade 130   Portugal      Porto      4050-359
# 17        Rua das Galeria de Paris, 113  Portugal      Porto      4050-284
# 18               Rua das Oliveiras, 118  Portugal      Porto      4050-448
# 19               Praça Dom Afonso V, 55  Portugal      Porto           NaN
# 20                           Rua de Diu  Portugal      Porto      4150-235
# 21  Avenida de Fernão de Magalhães, 500  Portugal      Porto           NaN
# 22                   Rua do Padrão, 152  Portugal      Porto           NaN
# 23                 Rua da Conceição, 59  Portugal      Porto           NaN
# 24                   Rua da Picaria, 87  Portugal      Porto           NaN
# 26         Rua de Cândido dos Reis, 126  Portugal      Porto           NaN
# 27                 Rua da Torrinha, 134  Portugal      Porto      4050-609
# 28               Avenida do Brasil, 829  Portugal      Porto      4150-154
# 29  Praça Dona Filipa de Lencastre, 183  Portugal      Porto           NaN
# 30                   Rua da Picaria, 89  Portugal      Porto          4050
# 31         Rua Professor Mota Pinto, 12  Portugal      Porto           NaN
#
#    data_abertura        lat       lon
# 0     2016-08-04  41.146372 -8.613946
# 1     2016-07-30  41.142930 -8.614492
# 2     2016-06-01  41.167065 -8.649931
# 3     2016-04-21  41.146143 -8.618476
# 4     2016-03-21  41.148893 -8.612156
# 5     2016-03-01  41.171641 -8.687910
# 6     2016-01-31  41.183414 -8.599088
# 7     2015-12-19  41.148199 -8.613973
# 8     2015-11-30  41.148052 -8.622642
# 9     2015-07-02  41.155805 -8.629691
# 11    2015-06-19  41.149990 -8.614575
# 12    2015-05-01  41.147646 -8.614940
# 13    2015-01-31  41.146421 -8.602091
# 14    2014-12-09  41.148305 -8.607553
# 15    2014-12-01  41.152751 -8.678126
# 16    2014-11-29  41.151326 -8.613884
# 17    2014-11-11  41.109916 -8.613941
# 18    2014-11-01  41.149783 -8.614720
# 19    2014-11-01  41.159324 -8.665371
# 20    2014-10-01  41.154677 -8.673512
# 21    2014-09-01  41.154347 -8.595674
# 22    2014-05-08  41.146091 -8.601548
# 23    2014-05-01  41.192876 -8.613317
# 24    2014-03-01  41.149611 -8.612989
# 26    2014-01-01  41.147423 -8.613768
# 27    2013-11-01  41.152565 -8.620043
# 28    2013-09-13  41.159052 -8.683298
# 29    2013-07-01  41.148350 -8.612598
# 30    2013-07-01  41.149632 -8.612989
# 31    2012-09-11  41.166845 -8.653087

# %% [markdown]
# # Mapear as hamburgarias!

# %%
df = pd.read_csv('data/hamburguerias_porto_latlon.csv')

# em windows? problemas de encoding? Importar assim:
# df = pd.read_csv('data/worldcitiespop.txt', encoding='ISO-8859-1')

df.head()
# Out:
#    Unnamed: 0                       nome                     morada      país  \
# 0           0          Honorato Clérigos   Rua Cândido dos Reis, 12  Portugal
# 1           1                     Prégar  Largo de São Domingos, 96  Portugal
# 2           2  Nook Hamburgaria Pregaria      Rua São João Brito 32  Portugal
# 3           3             Alta Burguesia      Rua da Restauração, 1  Portugal
# 4           4                    De Gema        Rua do Almada, 253   Portugal
#
#   localidade codigo_postal data_abertura        lat       lon
# 0      Porto      4050-151    2016-08-04  41.202399 -8.642936
# 1      Porto      4050-253    2016-07-30  41.142719 -8.614184
# 2      Porto           NaN    2016-06-01  41.221393 -8.552518
# 3      Porto           NaN    2016-04-21  41.194365 -8.574094
# 4      Porto      4050-038    2016-03-21  41.149802 -8.612104

# %%
# retirar entradas sem coordenadas
df = df.dropna(subset=['lat'])

# Vamos colocar os dados no mapa. 
m = folium.Map(location=[41.15134, -8.61477], zoom_start=14, tiles="stamentoner")

for index, row in df.iterrows():
    lat = float(row['lat'])
    lon = float(row['lon'])
    popup = row['nome'].replace("'", "&apos;") + ': ' + row['data_abertura']
    year = row['data_abertura'].split('-')[0]
    if int(year) > 2015:
        color = 'red'
    else:        
        color = 'green'
    folium.Marker([lat, lon], popup=popup, icon=folium.Icon(color=color)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
